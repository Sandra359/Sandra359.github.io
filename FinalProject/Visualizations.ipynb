# %%
import pandas as pd

df_mun = pd.read_csv('FinalData/all_data_mun.csv')
df_mun
# Out:
#      Municipality            Region  year  purchase_price_mean  \
# 0        Aabenraa  Southern Denmark  2008         1.631118e+06
# 1        Aabenraa  Southern Denmark  2009         1.535254e+06
# 2        Aabenraa  Southern Denmark  2010         1.577195e+06
# 3        Aabenraa  Southern Denmark  2011         1.499740e+06
# 4        Aabenraa  Southern Denmark  2012         1.564110e+06
# ...           ...               ...   ...                  ...
# 1661          Ærø  Southern Denmark  2020         1.093633e+06
# 1662          Ærø  Southern Denmark  2021         1.245801e+06
# 1663          Ærø  Southern Denmark  2022         1.209536e+06
# 1664          Ærø  Southern Denmark  2023         1.187258e+06
# 1665          Ærø  Southern Denmark  2024         1.229129e+06
#
#       purchase_price_median  sqm_price_mean  sqm_price_median    sqm_mean  \
# 0                 1065000.0       12842.465       8209.458984  142.541760
# ...

# %%
df_reg = pd.read_csv('FinalData/all_data_reg.csv')
df_reg
# Out:
#             Region  year  purchase_price_mean  purchase_price_median  \
# 0   Capital Region  2008         2.682002e+06              2434331.0
# 1   Capital Region  2009         2.455395e+06              2100000.0
# 2   Capital Region  2010         2.599042e+06              2295000.0
# 3   Capital Region  2011         2.557964e+06              2195000.0
# 4   Capital Region  2012         2.513142e+06              2175000.0
# ..             ...   ...                  ...                    ...
# 80  Zealand Region  2020         1.823485e+06              1450000.0
# 81  Zealand Region  2021         2.067815e+06              1655000.0
# 82  Zealand Region  2022         2.057488e+06              1650000.0
# 83  Zealand Region  2023         2.011127e+06              1600000.0
# 84  Zealand Region  2024         2.080557e+06              1650000.0
#
#     sqm_price_mean  sqm_price_median    sqm_mean  no_rooms_mean  \
# 0        22303.014      21229.114258  122.660730       4.255962
# ...
