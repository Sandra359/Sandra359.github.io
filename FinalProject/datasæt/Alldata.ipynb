# %%
import pandas as pd

# Read a Parquet file
df = pd.read_parquet("DKHousingPrices.parquet")

df
# Out:
#               date quarter  house_id   house_type    sales_type  year_build  \
# 0       2024-10-26  2024Q4         0        Villa  regular_sale        1974
# 1       2024-10-26  2024Q4         2  Summerhouse  regular_sale        1956
# 2       2024-10-26  2024Q4         1         Farm  regular_sale        1955
# 3       2024-10-25  2024Q4         3    Apartment   family_sale        1945
# 4       2024-10-25  2024Q4         4        Villa  regular_sale        1967
# ...            ...     ...       ...          ...           ...         ...
# 1507903 1992-01-05  1992Q1   1505861        Villa  regular_sale        1972
# 1507904 1992-01-05  1992Q1   1505860        Villa  regular_sale        1880
# 1507905 1992-01-05  1992Q1   1505859    Townhouse  regular_sale        1890
# 1507906 1992-01-05  1992Q1   1505858        Villa   family_sale        1972
# 1507907 1992-01-05  1992Q1   1505875        Villa  regular_sale        1989
#
# ...
